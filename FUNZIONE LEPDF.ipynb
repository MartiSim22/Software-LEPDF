# %%
# %matplotlib widget

# %% [markdown]
# Importo il widget di matplotlib per vedere interattivamente i grafici su Jupyter Lab

# %%
import pandas as pd

# %% [markdown]
# Importo la libreria Pandas

# %%
import camelot

# %% [markdown]
# Importo la liberia Camelot di python che serve per estrarre le tabelle contenute in fogli PDF

# %%
import numpy as np

# %% [markdown]
# Importo la libreria Numpy

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Importo la libreria Matplotlib

# %%
import os

# %% [markdown]
# Importo il modulo OS che fornisce funzioni per interagire con il sistema operativo

# %%
lista_anni = np.arange(2018,2021)
lista_mesi = np.arange(1,13)

# %% [markdown]
# Dichiaro due liste, una per gli anni e una per i mesi - QUI E' NECESSARIO L'INTERVENTO DELL'UTENTE

# %%
def configurazione(mese, anno):
    annomese = anno * 100 + mese 
    risultato = {}
    if (annomese == 201801):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['129,2090,3123,67'], 'columns' : ['373,444,517,591,661,735,811,890,972,1043,1122,1199,1275,1351,1428,1504,1580,1657,1736,1810,1886,1962,2036,2115,2188,2268,2344,2420,2500,2573,2652,2726,2799,2879,2955,3031']}
    if (annomese == 201802):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : True, 'area' : ['120,1740,2595,54'], 'columns' : ['313,388,448,507,572,634,694,769,842,901,964,1023,1080,1143,1205,1267,1327,1384,1446,1509,1568,1630,1690,1765,1825,1887,1947,2012,2071,2134,2191,2250,2313,2388,2450,2505']}
    if (annomese == 201803):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'], 'splittext' : True, 'area' : ['64,1700,2546,84'], 'columns' : ['266,332,394,455,514,591,650,724,799,860,924,978,1040,1102,1166,1225,1277,1339,1403,1468,1517,1576,1651,1728,1780,1855,1916,1978,2038,2092,2146,2208,2270,2344,2406,2458']}
    if (annomese == 201804):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'], 'splittext' : False, 'area' : ['46,1860,2656,59'], 'columns' : ['270,338,403,470,535,603,671,747,828,885,950,1010,1069,1134,1200,1267,1330,1384,1452,1517,1576,1641,1709,1774,1834,1912,1977,2042,2113,2173,2227,2295,2360,2438,2506,2563']}
    if (annomese == 201805):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['151,1810,2656,61'], 'columns' : ['365,433,496,557,622,683,746,824,900,950,1016,1071,1126,1187,1252,1318,1368,1421,1487,1550,1603,1666,1744,1819,1872,1948,2008,2071,2140,2192,2245,2311,2371,2444,2515,2565']}
    if (annomese == 201806):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['43,1788,2705,58'], 'columns' : ['241,305,370,440,502,569,639,719,800,862,926,1004,1069,1133,1201,1268,1335,1397,1461,1531,1593,1658,1725,1795,1859,1937,2002,2069,2134,2204,2265,2330,2397,2478,2545,2612']}
    if (annomese == 201807):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['34,1880,2754,51'], 'columns' : ['233,303,374,441,509,576,643,727,797,862,932,997,1061,1129,1196,1264,1337,1401,1469,1536,1604,1671,1739,1809,1876,1960,2027,2095,2162,2230,2300,2367,2437,2518,2588,2653']}
    if (annomese == 201808):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['30,1700,2582,34'], 'columns' : ['223,292,358,424,491,557,623,699,770,832,898,949,1001,1065,1133,1197,1251,1315,1384,1450,1514,1577,1641,1712,1779,1842,1906,1975,2043,2110,2174,2240,2306,2372,2441,2500']}
    if (annomese == 201809):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23,'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['32,1660,2585,64'], 'columns' : ['239,305,369,431,497,561,625,702,768,830,896,965,1029,1093,1156,1221,1283,1347,1409,1480,1534,1598,1665,1726,1791,1857,1916,1983,2049,2111,2172,2234,2300,2362,2426,2493']}
    if (annomese == 201810):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23,'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['299,1900,2940,213'], 'columns' : ['509,576,641,705,772,837,901,984,1061,1125,1195,1270,1332,1396,1463,1530,1592,1657,1721,1791,1853,1917,1979,2051,2113,2178,2242,2309,2374,2438,2502,2569,2634,2714,2781,2846']}
    if (annomese == 201811):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['88,1750,2815,48'], 'columns' : ['306,380,448,516,582,650,718,797,866,934,1005,1082,1148,1218,1285,1354,1421,1491,1555,1624,1691,1758,1827,1897,1964,2030,2097,2167,2236,2306,2370,2437,2506,2586,2653,2720']}
    if (annomese == 201812):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['207,1800,2799,50'], 'columns' : ['416,487,552,617,680,745,810,888,956,1019,1086,1137,1199,1265,1330,1398,1460,1526,1591,1659,1721,1787,1852,1920,1982,2045,2110,2176,2241,2309,2371,2437,2502,2577,2645,2708']}
    if (annomese == 201901):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['201,1930,2813,209'] , 'columns' : ['394,462,526,588,655,720,781,860,945,1000,1079,1139,1205,1272,1346,1413,1465,1532,1596,1675,1727,1792,1854,1944,1997,2063,2128,2194,2266,2336,2390,2454,2516,2592,2664,2723']}
    if (annomese == 201902):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : True , 'area' : ['58,1710,2538,63'] , 'columns' : ['333,396,459,511,580,641,705,777,847,903,964,1019,1082,1144,1206,1257,1311,1371,1434,1491,1545,1610,1671,1742,1797,1853,1923,1981,2037,2090,2142,2206,2267,2342,2401,2455']}
    if (annomese == 201903):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['170,1920,2853,119'] , 'columns' : ['379,454,524,590,656,724,792,873,961,1013,1091,1143,1210,1277,1353,1408,1466,1529,1600,1674,1725,1798,1876,1964,2015,2097,2166,2231,2308,2370,2419,2487,2555,2635,2710,2763']}
    if (annomese == 201904):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['52,1750,2740,33'] , 'columns' : ['257,342,407,472,538,601,670,754,844,894,979,1037,1103,1168,1248,1314,1379,1431,1496,1578,1628,1692,1763,1850,1904,1970,2035,2102,2182,2244,2298,2363,2434,2512,2590,2647']}
    if (annomese == 201905):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['68,1720,2586,62'] , 'columns' : ['280,352,417,483,549,615,681,757,833,884,950,1000,1065,1131,1198,1250,1299,1347,1415,1480,1530,1593,1672,1750,1799,1875,1939,2005,2073,2124,2173,2237,2301,2381,2445,2494']}
    if (annomese == 201906):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['147,1732,2660,49'] , 'columns' : ['345,432,496,562,626,694,758,836,906,966,1034,1082,1146,1214,1281,1332,1380,1444,1512,1578,1626,1692,1758,1823,1874,1950,2014,2078,2144,2197,2244,2310,2376,2454,2518,2570']}
    if (annomese == 201907):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['74,1580,2479,49'] , 'columns' : ['261,340,405,470,532,597,659,733,798,847,909,958,1022,1086,1157,1199,1246,1295,1360,1423,1472,1534,1599,1664,1710,1773,1833,1898,1963,2012,2063,2123,2188,2264,2326,2398']}
    if (annomese == 201908):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['34,1580,2443,29'] , 'columns' : ['238,305,368,435,501,566,633,707,776,824,891,940,1007,1072,1125,1175,1226,1273,1342,1391,1443,1508,1571,1641,1687,1752,1819,1884,1949,2000,2052,2117,2182,2249,2298,2363']}
    if (annomese == 201909):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['33,1750,2571,68'] , 'columns' : ['223,291,355,416,480,546,608,683,762,811,900,947,1007,1073,1156,1209,1266,1328,1392,1465,1519,1583,1642,1716,1770,1836,1895,1964,2035,2099,2155,2215,2280,2353,2431,2481']}
    if (annomese == 201910):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['71,1800,2810,118'] , 'columns' : ['283,363,432,499,566,636,700,780,868,930,1006,1077,1144,1211,1300,1358,1415,1482,1549,1626,1686,1755,1825,1902,1959,2029,2093,2163,2240,2307,2369,2433,2501,2580,2663,2717']}
    if (annomese == 201911):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['71,1800,2813,117'] , 'columns' : ['288,364,430,498,566,634,702,786,869,922,1014,1069,1135,1203,1296,1350,1410,1476,1544,1621,1680,1746,1816,1889,1950,2018,2086,2157,2238,2296,2359,2427,2497,2578,2657,2717']}
    if (annomese == 201912):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['85,1750,2723,87'] , 'columns' : ['290,366,434,498,566,628,695,772,853,904,990,1046,1111,1185,1249,1316,1372,1437,1504,1581,1636,1701,1769,1840,1898,1963,2030,2095,2169,2241,2290,2357,2424,2498,2573,2633']}
    if (annomese == 202001):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False , 'area' : ['31,1650,2579,40'], 'columns' : ['228,297,363,429,494,560,631,687,763,837,887,958,1010,1076,1142,1208,1274,1339,1408,1463,1529,1595,1666,1718,1787,1850,1921,1982,2037,2090,2171,2213,2282,2358,2432,2484']}
    if (annomese == 202002):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['34,1799,2776,34'], 'columns' : ['246,316,383,450,520,587,672,721,803,896,958,1042,1095,1165,1232,1299,1369,1433,1515,1571,1638,1708,1801,1854,1924,1988,2073,2137,2204,2262,2344,2397,2464,2543,2627,2683']}
    if (annomese == 202003):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 7 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['3,520,743,47'], 'columns' : ['71,85,108,122,141,158,184,196,213,237,258,276,290,314,332,349,365,387,405,424,442,456,479,493,515,533,551,574,591,603,626,640,658,681,699,713']}
    if (annomese == 202004):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['52,1720,2532,54'] , 'columns' : ['257,331,392,445,512,583,647,698,759,838,907,973,1034,1088,1145,1208,1272,1335,1402,1461,1526,1590,1650,1711,1776,1844,1906,1979,2033,2094,2158,2218,2285,2354,2414,2464']}
    if (annomese == 202005):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : True, 'area' : ['28,1580,2450,42','28,1660,2450,42'] , 'columns' : ['220,286,347,421,480,540,603,656,726,789,855,915,975,1036,1096,1157,1219,1282,1343,1403,1466,1521,1584,1642,1708,1771,1833,1891,1948,2013,2078,2134,2194,2259,2319,2377','220,286,347,421,480,540,603,656,726,789,855,915,975,1036,1096,1157,1219,1282,1343,1403,1466,1521,1584,1642,1708,1771,1833,1891,1948,2013,2078,2134,2194,2259,2319,2377']}
    if (annomese == 202006):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 20 , 'striptext' : ['\n','.'] , 'splittext' : True, 'area' : ['100,1668,2614,87'], 'columns' : ['291,358,423,485,548,612,688,742,807,880,940,1018,1072,1134,1197,1262,1324,1386,1462,1513,1575,1640,1716,1765,1829,1892,1967,2027,2097,2143,2219,2270,2349,2406,2481,2535']}
    if (annomese == 202007):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : True, 'area' : ['30,1710,2561,111'] , 'columns' : ['229,297,360,423,485,548,624,681,746,812,874,950,1008,1070,1136,1201,1261,1324,1389,1452,1512,1577,1642,1702,1768,1828,1898,1958,2023,2081,2151,2209,2279,2345,2407,2470']}
    if (annomese == 202008):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['40,1918,2827,108','40,1920,2827,108'] , 'columns' : ['267,342,411,481,547,619,694,760,841,915,982,1054,1120,1192,1264,1336,1403,1478,1550,1619,1688,1757,1832,1899,1971,2043,2115,2184,2256,2325,2398,2463,2536,2608,2680,2749','267,342,411,481,547,619,694,760,841,915,982,1054,1120,1192,1264,1336,1403,1478,1550,1619,1688,1757,1832,1899,1971,2043,2115,2184,2256,2325,2398,2463,2536,2608,2680,2749']}
    if (annomese == 202009):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23,'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['256,1900,2868,117'], 'columns' : ['463,534,602,667,735,803,873,925,1006,1085,1155,1225,1278,1346,1413,1481,1549,1614,1682,1737,1805,1870,1943,1995,2074,2144,2209,2267,2324,2377,2444,2499,2567,2648,2716,2771']}
    if (annomese == 202010):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 10,'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['112,1700,2606,160','112,1800,2606,160'] , 'columns' : ['339,385,450,514,574,639,701,763,825,888,954,1026,1093,1150,1220,1282,1342,1409,1469,1531,1595,1660,1722,1784,1847,1911,1976,2036,2106,2165,2232,2294,2358,2417,2484,2543','339,385,450,514,574,639,701,763,825,888,954,1026,1093,1150,1220,1282,1342,1409,1469,1531,1595,1660,1722,1784,1847,1911,1976,2036,2106,2165,2232,2294,2358,2417,2484,2543']}
    if (annomese == 202011):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : False, 'area' : ['34,1850,2825,34'] , 'columns' : ['247,320,385,458,523,597,675,735,816,898,957,1039,1098,1169,1253,1321,1380,1451,1535,1595,1665,1735,1820,1876,1950,2017,2102,2181,2243,2299,2384,2440,2511,2590,2674,2731']}
    if (annomese == 202012):
        risultato = {'ext' : 'pdf','pages' : 'all', 'flavor' : 'stream', 'rowtol' : 23 , 'striptext' : ['\n','.'] , 'splittext' : True, 'area' : ['31,1650,2580,88'] , 'columns' : ['235,304,376,436,498,561,624,684,759,825,890,965,1023,1086,1156,1223,1274,1341,1404,1469,1530,1592,1655,1720,1783,1846,1908,1974,2034,2097,2162,2222,2285,2362,2429,2484']}
    return risultato

# %% [markdown]
# Creo una funzione di configurazione che sceglie quali parametri utilizzare per ogni file. In questo caso in base al nome del file (es.2019_1) la funzione sceglie la condizione adatta da associare al file - QUI E' NECESSARIO L'INTERVENTO DELL'UTENTE

# %%
date_toskip = []

# %% [markdown]
# Dichiaro un array che contiene i nomi dei file che non devono essere estratti (es. non esistono o non sono interessato a estrarne le tabelle) - QUI E' NECESSARIO L'INTERVENTO DELL'UTENTE

# %%
function_count = 0

# %% [markdown]
# Inizializzo a 0 la variabile che conta il numero di volte in cui ho eseguito la funzione. Il valore di tale variabile verrà aggiornato ogni volta che eseguo la funzione.

# %%
all_tables =[]

# %% [markdown]
# Dichiaro un array vuoto in cui successivamente inserirò i valori di tutti i dataframe delle tabelle estratte dai miei file

# %%
colname={"PROVINCIA DI": "PROVINCIA", 
           "PROVINCIA DI RESIDENZA" : "PROVINCIA" ,
           "RYSLER/JEEP DODGE": "CHRYSLER/JEEP/DODGE", 
           "RYSLER/JEEP/DODGE": "CHRYSLER/JEEP/DODGE", 
           "CHRYSLER/JEEP DODGE" : "CHRYSLER/JEEP/DODGE",
           "CHRYSLER" : "CHRYSLER/JEEP/DODGE" ,
           "HRYSLER/JEEP/DODGE" : "CHRYSLER/JEEP/DODGE" , 
           "HRYSLER/JEEP DODGE" : "CHRYSLER/JEEP/DODGE",
           "CHRYSLER/JEEP  DODGE" : "CHRYSLER/JEEP/DODGE",
           "CHRYSLER/JEEP/ DODGE" : "CHRYSLER/JEEP/DODGE",
           "CITROEN" : "CITROEN/DS",
           'LFA ROMEO' : 'ALFA ROMEO', 
           'OYOTA/LEXUS' : 'TOYOTA/LEXUS',
           "TOYOTA" : "TOYOTA/LEXUS" ,
           "YOTA/LEXUS" : "TOYOTA/LEXUS" , 
           "OLKSWAGEN" : "VOLKSWAGEN" , 
           "AND ROVER" : "LAND ROVER" , 
           "SANGYONG" : "SSANGYONG",
           "SSANGJONG" : "SSANGYONG",
           "SLA MOTORS" : "TESLA MOTORS",
           "ESLA MOTORS" : "TESLA MOTORS",
           "Totale" : "TOTALE"}

# %% [markdown]
# Array contenente le ridenominazioni delle colonne delle mie tabelle qualora siano state estratte in maniera incompleta/errata. Lo scopo è di uniformare i nomi delle colonne di ogni tabella - QUI E' NECESSARIO L'INTERVENTO DELL'UTENTE

# %%
indexname = {'BARLETTA-ANDRIATRANI' : 'BARLETTA-ANDRIA-TRANI',
             'BRIANZA' : 'MONZA E DELLA BRIANZA',
             'BARI BARLETTA-' : 'BARI',
             'ANDRIA-TRANI' : 'BARLETTA-ANDRIA-TRANI',
             'ASCOLI PICENO' : 'ASCOLIPICENO'
            }

# %% [markdown]
# Array contenente le ridenominazioni delle righe delle mie tabelle qualora siano state estratte in maniera incompleta/errata. Lo scopo è di uniformare i nomi delle righe di ogni tabella - QUI E' NECESSARIO L'INTERVENTO DELL'UTENTE

# %%
subset=['DATA', 'PROVINCIA']

# %% [markdown]
# Lista contenente il nome/i delle colonne di cui voglio verificare i valori. La lista viene chiamata nella funzione "drop_duplicates" e permette di eliminare righe "doppie", ovvero righe i cui valori sono identici per le due colonne selezionate.

# %%
riga = ["MESSINA"]
colonna = ['DATA' , 'TOTALE']

# %% [markdown]
# Dichiaro due variabili che indicano il valore/i delle righe e il nome/i della colonne che voglio cercare nel file. - QUI E' NECESSARIO L'INTERVENTO DELL'UTENTE

# %%
print ("Inizio estrazione numero:",function_count+1)#inserisco un print che segnala l'inizio dell'estrazione
global function_count 
function_count += 1 
for anno in lista_anni:
    for mese in lista_mesi:       #scorro la lista degli anni e la lista dei mesi
        myconfig = configurazione(mese,anno)#richiamo qui la funzione di configurazione definita precedentemente 
        data=str(anno) + '_' + str(mese)
        if data in date_toskip: 
            continue
        file = os.path.abspath("DATI/" + data + '.' + myconfig['ext']) #apro i file dalla mia cartella e li trovo in base a come li ho rinominati - QUI E' NECESSARIO L'INTERVENTO DELL'UTENTE
        print("\nQuesto è il file:\t" + data + '.' + myconfig['ext']) #inserisco un print per visionare uno ad uno i file che il programma sta leggendo
        if (function_count==1) : #quando eseguo la funzione la prima volta 
            tables= camelot.read_pdf(file,  pages=myconfig['pages'], flavor=myconfig['flavor']) #eseguo la funzione read_pdf con i parametri BASE della mia configurazione -  QUI E' NECESSARIO L'INTERVENTO DELL'UTEN                      
            tables.n #salva il numero delle tabelle trovate in ogni file
            for i in range(0,tables.n):
                print("\nQuesta è la struttura della tabella numero:" , i+1)
                print('\n',tables[i]) #mi indica la struttura della tabella, quante colonne e righe ha 
                print(tables[i].parsing_report)
                print("\nQuesto grafico mostra il dato testuale ricavato dalla tabella:")
                camelot.plot(tables[i], kind='text').show()  #mostra come viene parsato il dato testuale da Camelot, utile per ricavare le coordinate delle colonne
                print("Questo grafico mostra l'area della tabella individuata per l'estrazione dei dati:")
                camelot.plot(tables[i], kind='contour').show() #grafico che mi mostra l'area della tabella presa in considerazione, utile per ricavare le coordinate da inserire per l'area
                temp_df = tables[i].df #grazie a Panda creo il dataframe della tabella
                temp_df1=tables[0].df
                df=temp_df.replace(r'^\s*$', np.nan, regex=True).rename(columns=temp_df1.iloc[0]).drop(temp_df.index[0]) #ogni tabella avrà come header i nomi delle colonne della prima riga estratta dalla tabella della prima pagina
                print("\nQuesto è il dataframe:\n\n", df,'\n')
                print("\nQueste sono le colonne:\n\n", df.columns,'\n')
        else : #quando eseguo la funzione dalla seconda volta in poi
            tables= camelot.read_pdf(file,  pages=myconfig['pages'], flavor=myconfig['flavor'],  row_tol=myconfig['rowtol'], strip_text=myconfig['striptext'] ,split_text=myconfig['splittext'], table_areas=myconfig['area'],  columns=myconfig['columns']) #eseguo la funzione read_pdf con i parametri precedentemente settati nella mia configurazione -  QUI E' NECESSARIO L'INTERVENTO DELL'UTEN                      
            tables.n #salva il numero delle tabelle trovate in ogni file
            for i in range(0,tables.n):
                print("\nQuesta è la struttura della tabella numero:" , i+1)
                print('\n',tables[i]) #mi indica la struttura della tabella, quante colonne e righe ha 
                print(tables[i].parsing_report)
                print("\nQuesto grafico mostra il dato testuale ricavato dalla tabella:")
                camelot.plot(tables[i], kind='text').show()  #mostra come viene parsato il dato testuale da Camelot, utile per ricavare le coordinate delle colonne
                print("Questo grafico mostra l'area della tabella individuata per l'estrazione dei dati:")
                camelot.plot(tables[i], kind='contour').show() #grafico che mi mostra l'area della tabella presa in considerazione, utile per ricavare le coordinate da inserire per l'area
                temp_df = tables[i].df #grazie a Panda creo il dataframe della tabella
                temp_df1=tables[0].df
                df=temp_df.replace(r'^\s*$', np.nan, regex=True).rename(columns=temp_df1.iloc[0]).drop(temp_df.index[0]) #ogni tabella avrà come header i nomi delle colonne della prima riga estratta dalla tabella della prima pagina
                df.rename(columns=colname, inplace=True)
                print("\nQuesto è il dataframe:\n\n", df,'\n')
                print("\nQueste sono le colonne:\n\n", df.columns,'\n')
                date=[] #creo un array vuoto in cui andrò a salvare la data corrispondente al file per ogni valore estratto
                for i in range (0, len(df)):
                    date.append(str(anno) + '-' + str(mese) + '-01')
                df['DATA']=date
                all_tables.append(df)
if (function_count > 1) :
    dftot=pd.concat(all_tables, axis=0, ignore_index=True) #concateno tutti i dataframe ricavati dalla lettura di ogni file
    dftot.drop_duplicates(subset=subset, inplace=True) #elimino le eventuali righe doppie
    dftot.fillna(0,inplace=True) #tutti i valori NAN diventano 0
    dftot.set_index("PROVINCIA" ,inplace=True) #settare il nuovo indice della tabella
    dftot.rename(index=indexname,inplace=True)
    brand = dftot.loc[riga, colonna] #richiamo le due variabili che contengono i valori della/e riga/righe e colonna/e da estrarre
    print('\nQuesta è la tabella con i miei brand scelti:\n')
    print(brand) #utilizzare il comando print(brand) per visualizzare il dataframe degli specifici valori che ho estratto
    brand.to_csv("MESSINA.csv") #è opportuno chiamare il file.csv con il nome del brand estratto, in questo caso si chiamerà come il nome della riga estratta - QUI E' NECESSARIO L'INTERVENTO DELL'UTENTE
# Out:
# Inizio estrazione numero: 2
#
# Questo è il file:	2018_1.pdf
#
# Questa è la struttura della tabella numero: 1
#
#  <Table shape=(64, 37)>
# {'accuracy': 100.0, 'whitespace': 11.53, 'order': 1, 'page': 1}
#
# Questo grafico mostra il dato testuale ricavato dalla tabella:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo grafico mostra l'area della tabella individuata per l'estrazione dei dati:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo è il dataframe:
#
#                  PROVINCIA ALFA ROMEO AUDI  BMW CHRYSLER/JEEP/DODGE CITROEN/DS  \
# 1               RESIDENZA        NaN  NaN  NaN                 NaN        NaN
# 2               AGRIGENTO         11   32    2                  39         29
# 3             ALESSANDRIA         18   57   34                  39         55
# 4                  ANCONA         29   78   20                  64         63
# 5                   AOSTA        476   28   29                 755        122
# ..                    ...        ...  ...  ...                 ...        ...
# 59  MONZA E DELLA BRIANZA         50  155  103                 100        101
# 60                 NAPOLI         30   90   57                 123        147
# 61                 NOVARA         29   91   34                  35         69
# 62                  NUORO          8    4  NaN                   5         17
# 63               ORISTANO          1    1  NaN                   4         27
#
#    DACIA  FIAT FORD HONDA  ... SKODA SMART SSANGYONG SUBARU SUZUKI  \
# 1    NaN   NaN  NaN   NaN  ...   NaN   NaN       NaN    NaN    NaN
# 2     28    87   22     2  ...   NaN   NaN       NaN      1      5
# 3     50   184   98     5  ...    11     2         2      1     49
# 4     60   198   74    10  ...    21     7         2    NaN     23
# 5     13  4503   43   NaN  ...    14    13       NaN      2     30
# ..   ...   ...  ...   ...  ...   ...   ...       ...    ...    ...
# 59    97   232  122    18  ...    38    24         9      3     62
# 60   128   399  191    16  ...    46    44         4      1     35
# 61    42   103   72     8  ...    21     2       NaN      3     49
# 62    22    27   13     3  ...     3   NaN         3    NaN      5
# 63    16    13   11     1  ...   NaN   NaN         1    NaN      9
#
#    TOYOTA/LEXUS VOLKSWAGEN VOLVO ALTRE TOTALE
# 1           NaN        NaN   NaN   NaN    NaN
# 2            11         40   NaN     0    492
# 3            33         78     4     1   1096
# 4            39        139     8     3   1312
# 5            26         23     7     0   6983
# ..          ...        ...   ...   ...    ...
# 59          214        280     6     3   2730
# 60           82        138     5     2   2695
# 61           48        109     2     0   1075
# 62           17         15   NaN     0    244
# 63            4         22   NaN     0    162
#
# [63 rows x 37 columns]
#
#
# Queste sono le colonne:
#
#  Index(['PROVINCIA', 'ALFA ROMEO', 'AUDI', 'BMW', 'CHRYSLER/JEEP/DODGE',
#        'CITROEN/DS', 'DACIA', 'FIAT', 'FORD', 'HONDA', 'HYUNDAI', 'INFINITI',
#        'JAGUAR', 'KIA', 'LANCIA', 'LAND ROVER', 'MASERATI', 'MAZDA',
#        'MERCEDES', 'MINI', 'MITSUBISHI', 'NISSAN', 'OPEL', 'PEUGEOT',
#        'PORSCHE', 'RENAULT', 'SEAT', 'SKODA', 'SMART', 'SSANGYONG', 'SUBARU',
#        'SUZUKI', 'TOYOTA/LEXUS', 'VOLKSWAGEN', 'VOLVO', 'ALTRE', 'TOTALE'],
#       dtype='object')
#
#
# Questa è la struttura della tabella numero: 2
#
#  <Table shape=(47, 37)>
# {'accuracy': 100.0, 'whitespace': 10.24, 'order': 1, 'page': 2}
#
# Questo grafico mostra il dato testuale ricavato dalla tabella:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo grafico mostra l'area della tabella individuata per l'estrazione dei dati:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo è il dataframe:
#
#               PROVINCIA ALFA ROMEO  AUDI   BMW CHRYSLER/JEEP/DODGE CITROEN/DS  \
# 1               PADOVA         62   127    60                  95         79
# 2              PALERMO         27    71    18                  79         34
# 3                PARMA         17    85    48                  36         53
# 4                PAVIA         32    22    40                  90        273
# 5              PERUGIA         42    64    36                 106         84
# 6        PESARO URBINO         20    40    22                  56         37
# 7              PESCARA          5    18    15                  33         47
# 8             PIACENZA         19    22    26                  42         49
# 9                 PISA         22    31    31                  61         64
# 10             PISTOIA         10    54    23                  62         50
# 11           PORDENONE         27    29    25                  27         41
# 12             POTENZA         11     6     7                  23         25
# 13               PRATO         14    19    27                  54         21
# 14              RAGUSA          5    29     1                  32         32
# 15             RAVENNA         16    26    22                  51         37
# 16  REGGIO DI CALABRIA          7    23     4                  25         30
# 17  REGGIO NELL'EMILIA         36    63    24                  67        104
# 18               RIETI          2     6     6                   8         12
# 19              RIMINI         10    28    20                  42         48
# 20                ROMA        112   229   328                 290        498
# 21              ROVIGO          3    32    23                  11         29
# 22             SALERNO         20    46    28                  61        121
# 23             SASSARI         17     4    12                  27         61
# 24              SAVONA         16    19     8                  16         45
# 25               SIENA         14    39    17                  39         34
# 26            SIRACUSA          4     7     7                  21         32
# 27             SONDRIO         10     8     4                  33          9
# 28        SUD SARDEGNA         15     5     5                  12         30
# 29             TARANTO          7    26    21                  18         24
# 30              TERAMO         19    12    15                  35         23
# 31               TERNI         10    13    12                  14         29
# 32              TORINO        719   265   171                 338        198
# 33             TRAPANI          9    23     4                  23         35
# 34              TRENTO        310   665   726                 377        441
# 35             TREVISO         53   129    42                 112        111
# 36             TRIESTE         13    23    17                  31         26
# 37               UDINE         34    38    36                  51         77
# 38              VARESE         53    87    81                 123         79
# 39             VENEZIA         37    89    29                 122         89
# 40            VERBANIA          5    17     7                  16         20
# 41            VERCELLI          7    20    11                  21         14
# 42              VERONA         48   161    68                  88        105
# 43       VIBO VALENTIA          2     5     4                  16         10
# 44             VICENZA         61    97    73                 133        106
# 45             VITERBO         11    14     9                  25         30
# 46              TOTALE       4520  6502  4832                7439       8994
#
#    DACIA   FIAT   FORD HONDA  ... SKODA SMART SSANGYONG SUBARU SUZUKI  \
# 1    114    331    168    15  ...    31    14         5     14     43
# 2     98    226     88     7  ...    18    20         1      1     23
# 3     78    146     80    18  ...    20     1         2    NaN     35
# 4     90    180    135     7  ...    10     5       NaN      1     57
# 5     63    385    124     8  ...    21    13       NaN      2     52
# 6     53    140     75     1  ...    12     5         2      3     22
# 7     20    132     49     4  ...     2    12       NaN    NaN     16
# 8     41     97     57     2  ...     5     1         3      1     12
# 9     79    232    132    15  ...    20   NaN         2    NaN     40
# 10    44    119     34     1  ...    12     4       NaN      1     38
# 11    31    103     81     6  ...    24     5         1      2     23
# 12    28    102     18   NaN  ...     5   NaN       NaN    NaN     12
# 13    40    136     43     1  ...     5     4         1      1     27
# 14    34     97     37     2  ...   NaN     3         2    NaN     12
# 15    61    100     93     7  ...    17     3       NaN      1     26
# 16    37     82     38    12  ...    12     6         1    NaN     15
# 17    78    283    144     7  ...    27     1         1      4     55
# 18     8     31     16     2  ...   NaN     1       NaN    NaN      4
# 19    39     80     51     9  ...    18     4         2      1     27
# 20   518    921    866    43  ...    46   383         5      7    158
# 21    27     32     52     2  ...    18     2         2    NaN     12
# 22    63    220     83     2  ...     9     7       NaN    NaN     27
# 23    38     76     65     1  ...     7     3         1    NaN     11
# 24    27     94     91     7  ...     1     2       NaN      1     30
# 25    57     90     51     3  ...     6     3       NaN      1     26
# 26    46     78     60     3  ...     3     2       NaN    NaN      7
# 27    10     62    112     2  ...     9   NaN       NaN      1     32
# 28    42     46     69   NaN  ...   NaN   NaN       NaN    NaN     10
# 29    47     77     44     9  ...    12     2       NaN    NaN     22
# 30    38    123     68     1  ...     2     5         1    NaN     15
# 31    23     50     37     1  ...     1   NaN         2    NaN      8
# 32   255   7915    481    33  ...    77    46        13      7    166
# 33    30     48     25   NaN  ...     1     1       NaN    NaN      3
# 34    60   1466   2134    11  ...   212   396         1     28     68
# 35    86    173    178    23  ...    33    17         6      8     50
# 36    16     76     35    10  ...     4    15         1      9     44
# 37    65    174     81     9  ...    19     5         4      2     54
# 38   105    162    165    20  ...    36     3         2      7    111
# 39    75    256    133     2  ...    27     8         3      4     38
# 40    10     47     31     2  ...     2   NaN       NaN      1     34
# 41    18     36     38    13  ...     1   NaN         1    NaN     26
# 42    98    250    160     9  ...   113    19         9      5     32
# 43    16     25     20   NaN  ...   NaN     1       NaN    NaN      4
# 44    95    624    183    24  ...    42    14         2      6     64
# 45    43     71     48     1  ...     3     3       NaN    NaN     15
# 46  6135  34470  12532   803  ...  2260  1570       184    244   3363
#
#    TOYOTA/LEXUS VOLKSWAGEN VOLVO ALTRE  TOTALE
# 1           179        248    12     5    2619
# 2            83        141     6     0    1520
# 3            62        143    18     0    1342
# 4            66         72     6     2    1759
# 5            62        178    14     2    1940
# 6            29        107   NaN     2    1039
# 7            34         40     7     1     703
# 8            53         41     2     0     832
# 9            55        145    15     0    1597
# 10           26         76     2     2     974
# 11           57         99    11     0     968
# 12            6         37   NaN     1     461
# 13           52         82     8     1     961
# 14           32         26     2     0     501
# 15           57        127    20     2    1153
# 16           70         31     3     2     647
# 17           76        124     6     1    1825
# 18            5         25   NaN     0     225
# 19           35         83   NaN     1     846
# 20          865        737    42    15   10099
# 21           33         71     3     0     591
# 22           29         99     2     0    1432
# 23           26         91     4     0     733
# 24           34         64     3     0     667
# 25           37         81    10     2     849
# 26           24         21     1     0     534
# 27           15         24   NaN     0     416
# 28           15         50   NaN     0     469
# 29            6         54     2     0     661
# 30           27         41     2     0     700
# 31           18         51   NaN     0     456
# 32          412        427    14    12   13440
# 33           21         45   NaN     0     445
# 34          967        691   144     5   12692
# 35          187        213    27     3    2329
# 36           43         38     2     0     576
# 37           83        129     9     1    1411
# 38          227        236    14     2    2582
# 39           95        145    18     7    1891
# 40            2         35     1     2     356
# 41           17         29     2     1     400
# 42          158        258    20     3    2576
# 43            7          6   NaN     0     216
# 44          209        163    28     5    2823
# 45           28         31     3     0     590
# 46         8335      13382  1095   186  177822
#
# [46 rows x 37 columns]
#
#
# Queste sono le colonne:
#
#  Index(['PROVINCIA', 'ALFA ROMEO', 'AUDI', 'BMW', 'CHRYSLER/JEEP/DODGE',
#        'CITROEN/DS', 'DACIA', 'FIAT', 'FORD', 'HONDA', 'HYUNDAI', 'INFINITI',
#        'JAGUAR', 'KIA', 'LANCIA', 'LAND ROVER', 'MASERATI', 'MAZDA',
#        'MERCEDES', 'MINI', 'MITSUBISHI', 'NISSAN', 'OPEL', 'PEUGEOT',
#        'PORSCHE', 'RENAULT', 'SEAT', 'SKODA', 'SMART', 'SSANGYONG', 'SUBARU',
#        'SUZUKI', 'TOYOTA/LEXUS', 'VOLKSWAGEN', 'VOLVO', 'ALTRE', 'TOTALE'],
#       dtype='object')
#
#
# Questo è il file:	2018_2.pdf
#
# Questa è la struttura della tabella numero: 1
#
#  <Table shape=(60, 37)>
# {'accuracy': 100.0, 'whitespace': 11.49, 'order': 1, 'page': 1}
#
# Questo grafico mostra il dato testuale ricavato dalla tabella:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo grafico mostra l'area della tabella individuata per l'estrazione dei dati:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo è il dataframe:
#
#                  PROVINCIA ALFA ROMEO  AUDI  BMW CHRYSLER/JEEP/DODGE  \
# 1               AGRIGENTO         11    11    1                  30
# 2             ALESSANDRIA         14    41   46                  36
# 3                  ANCONA         25    50   35                  68
# 4                   AOSTA        647    39   34                 605
# 5                  AREZZO          8    18   57                  52
# 6            ASCOLIPICENO         11     5   18                  29
# 7                    ASTI         13    11   43                  20
# 8                AVELLINO          4    27   10                  17
# 9                    BARI         28    32   16                  80
# 10   BARLETTA-ANDRIATRANI         -7     1   10                  14
# 11                BELLUNO         34     1    3                  59
# 12              BENEVENTO          6     5    3                  18
# 13                BERGAMO         51   112   78                  52
# 14                 BIELLA         11    10   18                  24
# 15                BOLOGNA         32   106   75                  92
# 16          BOLZANO-BOZEN        603  1170  786                 387
# 17                BRESCIA         50   117  109                 119
# 18               BRINDISI          2     9   14                  19
# 19               CAGLIARI         20    13   23                  27
# 20          CALTANISSETTA          3     4    4                   8
# 21             CAMPOBASSO          8     7    4                  20
# 22                CASERTA         20    21   26                  52
# 23                CATANIA          5    15   26                  32
# 24              CATANZARO          9    29   14                  31
# 25                 CHIETI         14     8   11                  31
# 26                   COMO         26    54   29                  64
# 27                COSENZA         18    30   20                  43
# 28                CREMONA         12    44   52                  29
# 29                CROTONE          2     1    2                   6
# 30                  CUNEO         31    45   36                  84
# 31                   ENNA          1     2  NaN                   7
# 32                  FERMO          6     5    4                  13
# 33                FERRARA         15    11   19                  33
# 34                FIRENZE        240   309  320                 230
# 35                 FOGGIA         13     7   11                  26
# 36          FORLI' CESENA          6    25   14                  34
# 37              FROSINONE         35    11   23                  57
# 38                 GENOVA         10    47   26                  24
# 39                GORIZIA          5     3    5                   7
# 40               GROSSETO          4     4   10                  10
# 41                IMPERIA          6     7    8                   9
# 42                ISERNIA          2     2    1                   4
# 43              LA SPEZIA          5    14    2                  46
# 44               L'AQUILA         12     4    4                  25
# 45                 LATINA         15    13   28                  27
# 46                  LECCE         30    31   29                  57
# 47                  LECCO         16    19   31                  34
# 48                LIVORNO          8    24   12                  26
# 49                   LODI         13    12   17                  21
# 50                  LUCCA         21    50   34                  54
# 51               MACERATA         13    21   30                  23
# 52                MANTOVA         18    18   41                  29
# 53          MASSA-CARRARA         13    28    8                  31
# 54                 MATERA         14   NaN   18                   8
# 55                MESSINA         12    37   27                  17
# 56                 MILANO        114   286  283                 253
# 57                 MODENA         42    66   95                  63
# 58  MONZA E DELLA BRIANZA         53   104   89                 104
# 59                 NAPOLI         32    73   76                 100
#
#    CITROEN/DS DACIA  FIAT FORD HONDA  ... SKODA SMART SSANGYONG SUBARU SUZUKI  \
# 1          17    10    69   27     3  ...     1   NaN         1    NaN      4
# 2          56    48   148  105     8  ...    11     4         2      2     41
# 3          59    50   171   51     9  ...    18     3         1      4     26
# 4         192    13  5426   58     4  ...    15    26         1      4     21
# 5          40    60   115   58     6  ...     8     6         3      2     28
# 6           2    32    74   29     3  ...     2     3         1    NaN     12
# 7          16    31    36   35     3  ...     2     1       NaN      1      7
# 8          28    23    45   32     1  ...     7     3       NaN      1      4
# 9          62    93   361  173    13  ...    24    20         6    NaN     66
# 10         10    12    34   10   NaN  ...     5   NaN         1    NaN     12
# 11         42    18   204   20   NaN  ...     8     1       NaN      3     15
# 12          7    20    27   11     2  ...     7     1       NaN    NaN      4
# 13        180   105   257  159    33  ...    26    21         4      6     37
# 14         11    38    46   45     4  ...     5     1       NaN    NaN     22
# 15        222   117   446  297    32  ...    46    10         4      9     64
# 16       2573   492  4303  641   NaN  ...   554   146       NaN      3     12
# 17        165   154   447  199    23  ...    46    26         3     10     51
# 18         17    28    88   25   NaN  ...   NaN     3       NaN    NaN      8
# 19         42    82   113  118    12  ...     1    13         1    NaN     14
# 20         15    12    43    6   NaN  ...     1   NaN       NaN    NaN      8
# 21         14     7    37   33   NaN  ...   NaN   NaN       NaN    NaN      8
# 22         44    80    97   61     8  ...    10     6         1      1      8
# 23         61    85    86   70    15  ...    17    11         1    NaN     39
# 24         47    18   103   37   NaN  ...     3     7       NaN    NaN     16
# 25         39    36   108   51     3  ...   NaN     6       NaN    NaN     12
# 26         55   101   232   91    11  ...    25    18         3      4     57
# 27         41    23   258   93     4  ...    11     6       NaN    NaN     17
# 28         53    34    55   67    15  ...    10     3       NaN    NaN     13
# 29         17     4    22    8   NaN  ...   NaN   NaN       NaN    NaN      5
# 30         87    51   198  113    13  ...    11    14         1      3     47
# 31          7    11     7    6     1  ...   NaN   NaN       NaN    NaN    NaN
# 32          3    11    32   17     4  ...     7     2       NaN      2      3
# 33         32    60    63   71   NaN  ...    18     1         2    NaN     17
# 34        285   179   759  456    35  ...   161    86         9     10     75
# 35          9    43    65   15     2  ...     1     3       NaN    NaN      8
# 36         31    64   110   81     9  ...     9     1         1    NaN     13
# 37         42    25   116   43     1  ...     6    10         3      2      6
# 38         36    71   157  184    11  ...     9    46         2      5     48
# 39          5    11    17    8    12  ...     3   NaN       NaN      1     18
# 40         24    22    48   28     3  ...     9     1         3    NaN     23
# 41         28    21    45   37     4  ...     4     6       NaN      3     16
# 42          4     6    17    9     1  ...   NaN     2       NaN    NaN      2
# 43         13    26    74   45    17  ...     7     5         5    NaN     10
# 44         39    32    92   18     1  ...     2     3         2    NaN     24
# 45         60    60   118   82     5  ...     9    14         2    NaN      9
# 46         37    79   137   75   NaN  ...     8     3       NaN    NaN     18
# 47         23    38   111   48     4  ...    18    13       NaN      5     34
# 48         29    51    71  147     2  ...    14     2         4      2     13
# 49         15    27    72   62     5  ...     3     1         1    NaN      9
# 50         47    69   182   73     1  ...    22     7         2      5     26
# 51         28    30    91   36     4  ...    18     3       NaN    NaN     21
# 52         79    45    51   45     3  ...    20   NaN         2      1     17
# 53         23    31    76   35   NaN  ...    13     1       NaN    NaN      8
# 54          1    22    73   16     5  ...     2   NaN       NaN    NaN      9
# 55         49    26   100   34     1  ...    10     9       NaN    NaN     10
# 56        683   419   696  648    66  ...   101    76        34     18    204
# 57         87   101   394  141     4  ...    37     4       NaN      5     35
# 58        125   143   225  136    27  ...    36    40         8      1     42
# 59        117   177   403  169    17  ...    39    41         3    NaN     42
#
#    TOYOTA/LEXUS VOLKSWAGEN VOLVO ALTRE TOTALE
# 1             9         43   NaN     0    399
# 2            30         68    12     0   1026
# 3            46        118     9     3   1171
# 4            14         29     5     0   7953
# 5            15        101     3     2    966
# 6             5         41     1     0    451
# 7             9         32     6     0    458
# 8            21         28     3     0    397
# 9            45        145    17     1   1930
# 10           28         21     2     0    255
# 11           15         31     6     1    640
# 12            1         15   NaN     1    254
# 13          182        333    14     5   2732
# 14           15         36     1     0    455
# 15          218        340    33    10   3283
# 16          395       3745    22     4  22783
# 17          166        368    19     3   3558
# 18            3         30   NaN     0    443
# 19           61         67     2     1    908
# 20            3         12   NaN     1    209
# 21            7         23   NaN     0    257
# 22           16         30     5     3    982
# 23           29         68   NaN     1   1154
# 24           22         52   NaN     0    608
# 25           32         85     1     1    683
# 26          114        204    14     2   1830
# 27           17        100   NaN     0   1033
# 28           59         91     7     1    946
# 29            7          3   NaN     0    123
# 30           81        122    16     1   1487
# 31            2         16   NaN     0    120
# 32           10         37     1     1    256
# 33           65        104     7     0    881
# 34          287        528   178     4   7010
# 35           37         22     1     3    458
# 36           30        104     8     0    936
# 37           17         76     1     0    728
# 38           70        210     7     0   1470
# 39           16         38     1     0    260
# 40           11         66     2     0    443
# 41           17         15     1     0    328
# 42            1          3     1     1     81
# 43           22         68     1     0    529
# 44           16         48     2     1    519
# 45           46         46     4     3    923
# 46            8         97     7     0   1156
# 47           53        115     1     1    920
# 48           40         92     5     0    946
# 49           20         48     4     1    583
# 50           48        128     9     1   1315
# 51           10        110     2     2    650
# 52           58         93    10     0   1011
# 53           16         73     1     1    540
# 54            5         15   NaN     0    290
# 55           21         59     2     0    755
# 56          638        687    95    22   8945
# 57          134        192    32     3   2319
# 58          181        227    10     3   2529
# 59           78        166    10     4   2646
#
# [59 rows x 37 columns]
#
#
# Queste sono le colonne:
#
#  Index(['PROVINCIA', 'ALFA ROMEO', 'AUDI', 'BMW', 'CHRYSLER/JEEP/DODGE',
#        'CITROEN/DS', 'DACIA', 'FIAT', 'FORD', 'HONDA', 'HYUNDAI', 'INFINITI',
#        'JAGUAR', 'KIA', 'LANCIA', 'LAND ROVER', 'MASERATI', 'MAZDA',
#        'MERCEDES', 'MINI', 'MITSUBISHI', 'NISSAN', 'OPEL', 'PEUGEOT',
#        'PORSCHE', 'RENAULT', 'SEAT', 'SKODA', 'SMART', 'SSANGYONG', 'SUBARU',
#        'SUZUKI', 'TOYOTA/LEXUS', 'VOLKSWAGEN', 'VOLVO', 'ALTRE', 'TOTALE'],
#       dtype='object')
#
#
# Questa è la struttura della tabella numero: 2
#
#  <Table shape=(50, 37)>
# {'accuracy': 99.69, 'whitespace': 11.95, 'order': 1, 'page': 2}
#
# Questo grafico mostra il dato testuale ricavato dalla tabella:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo grafico mostra l'area della tabella individuata per l'estrazione dei dati:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo è il dataframe:
#
#               PROVINCIA ALFA ROMEO  AUDI   BMW CHRYSLER/JEEP/DODGE CITROEN/DS  \
# 1               NOVARA         20    43    50                  33         68
# 2                NUORO         10     2     1                   1         12
# 3             ORISTANO          5     3     1                   2         20
# 4               PADOVA         46    92    73                 103         83
# 5              PALERMO         20    58    15                  59         29
# 6                PARMA         21    60    68                  33         42
# 7                PAVIA         29    35    43                  65        188
# 8              PERUGIA         25    55    44                  73         79
# 9        PESARO URBINO         14    27    28                  40         25
# 10             PESCARA          9     9    29                  24         50
# 11            PIACENZA          6    24    25                  36         50
# 12                PISA         25    18    49                  68         51
# 13             PISTOIA         10     9    17                  50         47
# 14           PORDENONE         18    22    49                  23         31
# 15             POTENZA         16     7     4                  21         21
# 16               PRATO          9    11    27                  45         20
# 17              RAGUSA         11     9     2                  26         28
# 18             RAVENNA          8    30    22                  53         20
# 19  REGGIO DI CALABRIA         10    15     6                  22         22
# 20  REGGIO NELL'EMILIA         32    55    46                  91        109
# 21               RIETI          6     1     4                   9          8
# 22              RIMINI          6    24    36                  35         31
# 23                ROMA         97   145   315                 261        490
# 24              ROVIGO          4    26    39                   8         34
# 25             SALERNO         25    29    26                  66         99
# 26             SASSARI          8     8     7                  27         51
# 27              SAVONA          7     7     6                  26         40
# 28               SIENA         13    36    14                  35         38
# 29            SIRACUSA          4     6    10                   9         17
# 30             SONDRIO          9     6     6                  19          8
# 31        SUD SARDEGNA         15     4     2                  15         34
# 32             TARANTO          4    16    17                  24         13
# 33              TERAMO         17    11    14                  33         12
# 34               TERNI         14    10    16                  17         33
# 35              TORINO        823   174   180                 795        179
# 36             TRAPANI          5    13     1                  12         34
# 37              TRENTO        315   848   929                 417        460
# 38             TREVISO         29    63    40                 107         80
# 39             TRIESTE         19    19    33                  34         11
# 40               UDINE         25    50    55                  53         69
# 41              VARESE         46    74    97                  71         88
# 42             VENEZIA         37    48    19                 122         73
# 43            VERBANIA          5     7     9                  17         20
# 44            VERCELLI          7     8    12                  10          8
# 45              VERONA         48   107    87                  64         71
# 46       VIBO VALENTIA          3     5     1                  17          3
# 47             VICENZA         70    75    71                 139         87
# 48             VITERBO          5     8     5                  24         31
# 49              TOTALE       4509  5681  5518                6854       9292
#
#    DACIA   FIAT   FORD HONDA  ... SKODA SMART SSANGYONG SUBARU SUZUKI  \
# 1     48     92     57     9  ...    12     1         1    NaN     30
# 2     30     16     10   NaN  ...     1   NaN         2    NaN      2
# 3     24      9      5   NaN  ...   NaN   NaN         1    NaN      2
# 4     82    259    142    17  ...    35    19         6     11     39
# 5    123    200     69     7  ...    16    37         1      3     21
# 6     51    148     74    13  ...    21     1         1      6     23
# 7     89    143    131    16  ...     6     5         2      3     42
# 8     36    292     96    10  ...    22    15       NaN      5     65
# 9     50    117     71     2  ...    11    11         1      1     21
# 10    31     84     48     6  ...     3     9       NaN      3      8
# 11    19    128     62     5  ...     9     2         1      3     22
# 12    73    181    135    14  ...    16     4         2    NaN     23
# 13    55     78     38     1  ...    23     5       NaN    NaN     17
# 14    21    111     63     3  ...    12     2         2      1     22
# 15    21    114     23   NaN  ...     6     2       NaN    NaN     12
# 16    47    107     41     1  ...     6     9         2      2     25
# 17    28     79     29     1  ...   NaN     1         2    NaN      5
# 18    47     90     85     6  ...    16     3       NaN      3     28
# 19    45     70     34    11  ...    10     9         2    NaN      6
# 20    95    262    130     3  ...    20     1         1      3     34
# 21    13     28     26   NaN  ...   NaN     3       NaN    NaN      3
# 22    42     82     44    12  ...    12     3       NaN    NaN     18
# 23   494    977    890    54  ...    46   526        10      4    158
# 24    12     26     40     2  ...     8   NaN         4      1      5
# 25    63    260     73     1  ...     3    16       NaN    NaN     23
# 26    45     89     48     1  ...     5     5       NaN    NaN      6
# 27    30     62     67     9  ...     2     3       NaN      2     22
# 28    58     74     55     4  ...     7   NaN         1      6     24
# 29    72     74     58     5  ...     2   NaN       NaN    NaN      4
# 30     9     47    151     2  ...    11     3       NaN      4     28
# 31    50     53     63   NaN  ...   NaN   NaN         1    NaN      5
# 32    38     63     42     3  ...     8     4       NaN    NaN     15
# 33    31    110     54   NaN  ...     2     3         2    NaN      5
# 34    25     37     32     1  ...     3     3       NaN    NaN     10
# 35   296   5878    477    36  ...    71    44        20     13    135
# 36    27     27     18   NaN  ...     4     2         1    NaN      2
# 37    81   1959   2881     7  ...   213   253         2     11    206
# 38    73    102    140    25  ...    23    16         1     12     39
# 39    21     68     38    13  ...     5    13         3     10     28
# 40    70    184     81    14  ...    16     6         5      2     31
# 41   151    170    134    30  ...    29     8         4     12    125
# 42   115    253    147     3  ...    28     7         1      2     33
# 43    23     46     28     6  ...     8   NaN       NaN      1     21
# 44    29     29     40    13  ...     1     1         2      3     17
# 45    90    178    162    14  ...    82    16        13      4     48
# 46     9     23     14   NaN  ...   NaN     2       NaN    NaN      3
# 47    63    828    170    21  ...    39     5         3      5     52
# 48    52     51     37   NaN  ...     2     4       NaN      2     19
# 49  6874  32409  12841   871  ...  2335  1821       217    251   2970
#
#    TOYOTA/LEXUS VOLKSWAGEN VOLVO ALTRE  TOTALE
# 1            44         91     3     4     962
# 2            20         22     1     0     240
# 3           NaN         19   NaN     0     154
# 4           142        313    17     3    2476
# 5            72        122     6     2    1434
# 6            56        149    14     0    1292
# 7            66         89    10     0    1579
# 8            91        214    68     1    1832
# 9            21         94     3     3     912
# 10           32         35     7     0     655
# 11           25         55     5     0     798
# 12           47        195    16     0    1511
# 13           19         80     7     1     838
# 14           51         74    13     0     901
# 15            6         40   NaN     1     451
# 16           41         99     5     0     910
# 17           25         30   NaN     4     451
# 18           42        116    17     0    1079
# 19           57         29     3     1     596
# 20           55        157    11     0    1768
# 21            5         14   NaN     1     223
# 22           28         73     7     0     785
# 23          772        769    18     8    9977
# 24           25         86     2     1     520
# 25           25        107     2     1    1372
# 26           27         97     4     0     824
# 27           21         67     9     1     567
# 28           24         88    10     0     835
# 29           27         16   NaN     0     513
# 30           20         30     8     0     464
# 31           17         42   NaN     1     456
# 32            2         70     1     0     631
# 33           14         46     4     0     607
# 34           18         54     1     3     431
# 35          423        425    13    26   11815
# 36           16         55   NaN     0     392
# 37         1438        747   140     3   16329
# 38          139        248    19     1    1910
# 39           22         48     1     2     548
# 40           72        139    14     1    1469
# 41          215        261    19     2    2596
# 42          106        177    11     3    1930
# 43           12         27   NaN     1     372
# 44           19         31     3     1     379
# 45          131        301    12     5    2322
# 46            4         11   NaN     1     172
# 47          145        220    32     3    3006
# 48           26         42     4     2     529
# 49         8327      16178  1141   179  181734
#
# [49 rows x 37 columns]
#
#
# Queste sono le colonne:
#
#  Index(['PROVINCIA', 'ALFA ROMEO', 'AUDI', 'BMW', 'CHRYSLER/JEEP/DODGE',
#        'CITROEN/DS', 'DACIA', 'FIAT', 'FORD', 'HONDA', 'HYUNDAI', 'INFINITI',
#        'JAGUAR', 'KIA', 'LANCIA', 'LAND ROVER', 'MASERATI', 'MAZDA',
#        'MERCEDES', 'MINI', 'MITSUBISHI', 'NISSAN', 'OPEL', 'PEUGEOT',
#        'PORSCHE', 'RENAULT', 'SEAT', 'SKODA', 'SMART', 'SSANGYONG', 'SUBARU',
#        'SUZUKI', 'TOYOTA/LEXUS', 'VOLKSWAGEN', 'VOLVO', 'ALTRE', 'TOTALE'],
#       dtype='object')
#
#
# Questo è il file:	2018_3.pdf
#
# Questa è la struttura della tabella numero: 1
#
#  <Table shape=(59, 37)>
# {'accuracy': 100.0, 'whitespace': 11.82, 'order': 1, 'page': 1}
#
# Questo grafico mostra il dato testuale ricavato dalla tabella:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo grafico mostra l'area della tabella individuata per l'estrazione dei dati:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo è il dataframe:
#
#                  PROVINCIA ALFA ROMEO  AUDI  BMW CHRYSLER/JEEP/DODGE  \
# 1               RESIDENZA        NaN   NaN  NaN                  CH
# 2               AGRIGENTO          5    20    3                  23
# 3             ALESSANDRIA         12    29   51                  46
# 4                  ANCONA         27    52   42                  76
# 5                   AOSTA       1051    41   25                1007
# 6                  AREZZO         14    37   24                  68
# 7            ASCOLIPICENO         14     6   18                  29
# 8                    ASTI          4    17   23                  20
# 9                AVELLINO          2    22   11                  17
# 10                   BARI         57    39   23                 129
# 11  BARLETTA-ANDRIA-TRANI          2     2   11                  14
# 12                BELLUNO         34     8    6                  84
# 13              BENEVENTO          4    11    5                  25
# 14                BERGAMO         46   127  123                 110
# 15                 BIELLA         11    17   16                  23
# 16                BOLOGNA         43   103   91                 111
# 17          BOLZANO-BOZEN        781  1724  373                 425
# 18                BRESCIA         85   160  176                 186
# 19               BRINDISI          4   NaN   11                  18
# 20               CAGLIARI         29    16   12                  32
# 21          CALTANISSETTA        NaN     4    5                   8
# 22             CAMPOBASSO          4     9    5                  20
# 23                CASERTA         24    19   23                  61
# 24                CATANIA          5    25   18                  31
# 25              CATANZARO         11    21   17                  37
# 26                 CHIETI          9     4   14                  47
# 27                   COMO         13    59   41                 104
# 28                COSENZA         14    53   24                  53
# 29                CREMONA          7    40   38                  23
# 30                CROTONE          1     3  NaN                   7
# 31                  CUNEO         21    46   57                 116
# 32                   ENNA          1     4    3                   1
# 33                  FERMO          4     7   13                  11
# 34                FERRARA          9    15   14                  29
# 35                FIRENZE        200   304  257                 415
# 36                 FOGGIA          5    17   14                  33
# 37          FORLI' CESENA          5    23   14                  55
# 38              FROSINONE         31    21   27                  73
# 39                 GENOVA         19    46   33                  39
# 40                GORIZIA          2     6    9                  10
# 41               GROSSETO          2     9    4                  21
# 42                IMPERIA          3     4    6                  11
# 43                ISERNIA          2   NaN    4                   5
# 44              LA SPEZIA          7     5    9                  27
# 45               L'AQUILA          2    15   11                  21
# 46                 LATINA         13    11   27                  46
# 47                  LECCE         16    35   27                  62
# 48                  LECCO         19    33   21                  72
# 49                LIVORNO          7    27   19                  40
# 50                   LODI          6    22   21                  28
# 51                  LUCCA         16    45   28                  78
# 52               MACERATA         10    19   25                  34
# 53                MANTOVA         19    37   42                  35
# 54          MASSA-CARRARA          7    35    9                  49
# 55                 MATERA         12   NaN   11                   6
# 56                MESSINA          7    29   23                  34
# 57                 MILANO        114   306  351                 260
# 58                 MODENA         46    58   89                  74
#
#    CITROEN/DS DACIA  FIAT  FORD HONDA  ... SKODA SMART SSANGYONG SUBARU  \
# 1         NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN       NaN    NaN
# 2          14     8   103    37     3  ...     1     1       NaN      1
# 3          70    27   201   119     2  ...     7     7       NaN    NaN
# 4          79    40   260    72    15  ...    17     5       NaN    NaN
# 5         311     9  4735    70     8  ...    19    14         1      1
# 6          38    23   173    83    11  ...    14     9         4      1
# 7           2    17    97    35     1  ...     2     2         3    NaN
# 8          15    26    57    53     4  ...     3   NaN       NaN    NaN
# 9          30    23    87    41   NaN  ...     5     2       NaN    NaN
# 10         87    65   538   210    17  ...    21    34         6    NaN
# 11          4    11    47    28   NaN  ...     6   NaN       NaN    NaN
# 12         64    28   252    38     1  ...    13     1       NaN      7
# 13         13    12    68    26   NaN  ...     7     5         1    NaN
# 14        232    95   330   158    29  ...    47    28         4      4
# 15         19    10    77    43     9  ...     3     1       NaN      2
# 16        211    98   447   320    32  ...    46    13         7     10
# 17       2559   551  5934  2181     1  ...   554   507         1      3
# 18        172   104   575   262    20  ...    37    32         7     12
# 19          9    21    93    28   NaN  ...     3     4       NaN    NaN
# 20         62    76   133   107     9  ...     1    18       NaN    NaN
# 21         14     7    48    12   NaN  ...     1   NaN       NaN    NaN
# 22          8     6    51    35   NaN  ...     1   NaN         1    NaN
# 23         43    42   156    70     6  ...    16     8         1      1
# 24         56    54   148    98    15  ...    23    19         2    NaN
# 25         44    14   147    43     1  ...     6    12       NaN      2
# 26         33    16   176    66     8  ...     3     7       NaN      1
# 27         73    47   292    87    11  ...    35    24         3     11
# 28         62    19   282   124     1  ...    13     4         2    NaN
# 29         66    25    84    85    11  ...     8     7       NaN      1
# 30         13     7    38     9   NaN  ...   NaN   NaN       NaN    NaN
# 31        137    34   266   189    24  ...    26    30         1    NaN
# 32          7     6    24     8   NaN  ...     1     1       NaN    NaN
# 33          3    11    56    23     3  ...     4     5         3      3
# 34         28    26   113    80     2  ...    17     7         2      3
# 35        196   102  1389   558    33  ...   192    96         9     10
# 36         21    23    72    35     6  ...     5     9       NaN      1
# 37         32    49   188   104    15  ...    12     1       NaN      1
# 38         39    10   149    40     3  ...     3    11         3      2
# 39         24    46   250   226    19  ...     8    66       NaN      3
# 40          8     9    15    77    15  ...     5     1       NaN    NaN
# 41         30    22    54    37     6  ...     6     3         3    NaN
# 42         21    13    47    37     8  ...     6     2         1      1
# 43          4     3    11    11   NaN  ...   NaN     1       NaN    NaN
# 44         31    12   127    29   NaN  ...     1     2         2    NaN
# 45         19    21    99    52     7  ...     1     4         1      1
# 46         61    38   121    83     6  ...     7    23         3      1
# 47         22    55   153   109   NaN  ...    15     8       NaN    NaN
# 48         44    26   135    51     6  ...    19     5         4      6
# 49         26    49   144   167     3  ...    11   NaN         9    NaN
# 50         15    15    78    72     6  ...     7     1         1    NaN
# 51         49    53   227    93     5  ...    19     2         3      3
# 52         25    20   147    58     4  ...    23     2       NaN      3
# 53         78    21    92    52     2  ...    22     2       NaN    NaN
# 54         12    19    92    49     3  ...    17     1         1    NaN
# 55          3    11    63    29     3  ...     2     2       NaN      1
# 56         61    45   143    58   NaN  ...     7    25         2    NaN
# 57        597   220   953   696    82  ...   128   430        35     24
# 58         90    74   352   154    12  ...    39     4       NaN      6
#
#    SUZUKI TOYOTA/LEXUS VOLKSWAGEN VOLVO ALTRE TOTALE
# 1     NaN            T          V   NaN   NaN    NaN
# 2       3            7         51   NaN     0    459
# 3      23           48        106    13     1   1184
# 4      28           73        183    14     9   1544
# 5      16           25         37     8     0   8741
# 6      18           21        132     6     1   1066
# 7      18           12         43     5     0    524
# 8      19           19         49     5     0    556
# ...
# 21            8          8   NaN     1    178
# 22           12         13     1     0    174
# 23           48         36     1     1    811
# 24           79         96   NaN     4   1072
# 25           30         44   NaN     1    515
# 26           39         34     1     3    558
# 27          131        164    26     8   1352
# 28           40         68     1     1    774
# 29           48         76     2     1    742
# 30            9         10   NaN     0     99
# 31           76        121    26     7   1320
# 32            3         10   NaN     0    106
# 33           16         28   NaN     1    263
# 34           82         64     8     1    660
# 35          491        470   488    18   6335
# 36           32         16   NaN     4    381
# 37           41         78    13     3    692
# 38           28         89     5     3    667
# 39          122        267    18     3   1390
# 40           12         16   NaN     2    180
# 41            9         47     3     0    310
# 42           35         22     2     0    238
# 43            6          2     1     0     76
# 44           23         87   NaN     0    435
# 45           26         54     1     6    458
# 46           53         55     3     5    791
# 47           25         82     1     4    760
# 48           54         86     7     0    653
# 49           35         66     3     2    610
# 50           22         56     2     1    440
# 51           67        109     8     2    962
# 52           35         85    15     1    627
# 53           48         59    18     0    723
# 54           20         62     5     2    420
# 55            2         18   NaN     1    267
# 56           46         61     4     5    766
#
# [56 rows x 37 columns]
#
#
# Queste sono le colonne:
#
#  Index(['PROVINCIA', 'ALFA ROMEO', 'AUDI', 'BMW', 'CHRYSLER/JEEP/DODGE',
#        'CITROEN/DS', 'DACIA', 'DR', 'FIAT', 'FORD', 'HONDA', 'HYUNDAI',
#        'JAGUAR', 'KIA', 'LANCIA', 'LAND ROVER', 'MAZDA', 'MERCEDES', 'MINI',
#        'MITSUBISHI', 'NISSAN', 'OPEL', 'PEUGEOT', 'PORSCHE', 'RENAULT', 'SEAT',
#        'SKODA', 'SMART', 'SSANGYONG', 'SUBARU', 'SUZUKI', 'TESLA MOTORS',
#        'TOYOTA/LEXUS', 'VOLKSWAGEN', 'VOLVO', 'ALTRE', 'TOTALE'],
#       dtype='object')
#
#
# Questa è la struttura della tabella numero: 2
#
#  <Table shape=(55, 37)>
# {'accuracy': 99.71, 'whitespace': 11.11, 'order': 1, 'page': 2}
#
# Questo grafico mostra il dato testuale ricavato dalla tabella:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo grafico mostra l'area della tabella individuata per l'estrazione dei dati:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Questo è il dataframe:
#
#                  PROVINCIA ALFA ROMEO  AUDI   BMW CHRYSLER/JEEP/DODGE  \
# 1               RESIDENZA        NaN   NaN   NaN                   C
# 2                  MILANO        135   162   241                 122
# 3                  MODENA          7    42    55                  42
# 4   MONZA E DELLA BRIANZA         19    48    39                  97
# 5                  NAPOLI         25    47    43                  90
# 6                  NOVARA          5    41    19                  30
# 7                   NUORO          2     3     1                   1
# 8                ORISTANO          2     1     1                   6
# 9                  PADOVA         18    49    50                  68
# 10                PALERMO         11    42    24                  91
# 11                  PARMA          2    39    22                  30
# 12                  PAVIA         15    18    36                  35
# 13                PERUGIA         12    36    33                  55
# 14          PESARO URBINO          4    30    15                  29
# 15                PESCARA          4    10    10                  24
# 16               PIACENZA        NaN    23    22                   9
# 17                   PISA          9    38    30                  59
# 18                PISTOIA        NaN    20    16                  16
# 19              PORDENONE         16     8    20                  26
# 20                POTENZA          2     6     5                  30
# 21                  PRATO          9     9    36                  21
# 22                 RAGUSA          5    10     4                  27
# 23                RAVENNA          2    16    16                  62
# 24     REGGIO DI CALABRIA          3    18     9                  25
# 25     REGGIO NELL'EMILIA          5    37    29                  42
# 26                  RIETI          1     4     6                  10
# 27                 RIMINI          7    13    15                  28
# 28                   ROMA         34   119   206                 248
# 29                 ROVIGO          1     7    20                   5
# 30                SALERNO         14    21    19                  56
# 31                SASSARI        NaN    11     5                  36
# 32                 SAVONA          5     8    13                  17
# 33                  SIENA          6     9    15                  23
# 34               SIRACUSA          1     4     8                  23
# 35                SONDRIO          2     3     3                   4
# 36           SUD SARDEGNA          5     7     2                  15
# 37                TARANTO          2    17    11                  23
# 38                 TERAMO          6     8     8                  21
# 39                  TERNI          2    15     8                  22
# 40                 TORINO         93   140   120                 574
# 41                TRAPANI          1     5     9                  19
# 42                 TRENTO         48   283   695                  90
# 43                TREVISO         20    52    47                  74
# 44                TRIESTE        NaN    11     4                  10
# 45                  UDINE         12    39    26                  31
# 46                 VARESE         34    40    66                  72
# 47                VENEZIA         15    27    33                  55
# 48               VERBANIA          6     4     8                   5
# 49               VERCELLI          3     5     3                   4
# 50                 VERONA         19    63    96                  49
# 51          VIBO VALENTIA        NaN     5     2                   6
# 52                VICENZA         18    55    45                 155
# 53                VITERBO          3    11    11                  23
# 54                 TOTALE       1664  3770  3525                5458
#
#    CITROEN/DS DACIA   DR   FIAT  FORD  ... SMART SSANGYONG SUBARU SUZUKI  \
# 1         NaN   NaN  NaN    NaN   NaN  ...   NaN       NaN    NaN    NaN
# 2         327   182   32    831   394  ...     8        14      7    189
# 3          77    35    7    294   109  ...   NaN         3      3     23
# 4          73    46    3    190   102  ...     1         2      5     34
# 5         175   142    4    424    95  ...   NaN         2      1     44
# 6          36    30  NaN     87    36  ...   NaN       NaN    NaN     31
# 7          10    11  NaN     22     5  ...   NaN       NaN    NaN    NaN
# 8          17    12  NaN     12    11  ...   NaN       NaN    NaN      2
# 9          97    51    4    304   119  ...     2         5      9     26
# 10        105    75    7    219    40  ...   NaN         1      3     38
# 11         32    29    5     96    53  ...   NaN       NaN      5      8
# 12         48    33    3    123    90  ...     1       NaN      2     18
# 13         75    24  NaN    285    62  ...     1         3      2     39
# 14         36    27    2    110    50  ...     2       NaN      3     12
# 15         41    21    2     90    23  ...     1         1      1     11
# 16          8    16    1     78    41  ...   NaN         1      3     10
# 17         37    62    4    172    63  ...   NaN       NaN      1     22
# 18         15    42  NaN     83    13  ...   NaN         1      1      4
# 19         30    14    4     88    36  ...     1       NaN      1      6
# 20         17     3    1    156    12  ...   NaN       NaN    NaN     11
# 21         32    25    1    107    15  ...     1       NaN      1      5
# 22         36    20    1     85    32  ...   NaN       NaN    NaN     14
# 23         35    26    2     87    62  ...   NaN       NaN      2     21
# 24         19    39    4    115    36  ...   NaN         1    NaN      9
# 25         87    45    2    258    77  ...     1       NaN      3     22
# 26          7    10  NaN     42    10  ...   NaN       NaN    NaN      4
# 27         30    25    2     71    24  ...     1         2      1     14
# 28        336   326   21   1142   550  ...    45       NaN     24    261
# 29         20    12    4     38    28  ...   NaN         1      1      5
# 30        119    36    2    232    70  ...     1       NaN    NaN     12
# 31         36    22    1     74    41  ...   NaN       NaN    NaN      5
# 32         33     9    1     65    33  ...   NaN       NaN      4     20
# 33         22    18    2     71    39  ...     1         1      2      9
# 34         24    35    6    126    31  ...   NaN       NaN    NaN      1
# 35          9     5  NaN     27    70  ...   NaN       NaN      3      5
# 36         29    26  NaN     34    30  ...   NaN       NaN    NaN      2
# 37         25    18  NaN     89    34  ...   NaN       NaN    NaN      8
# 38         19    28  NaN    112    16  ...     1         3    NaN      6
# 39         36    22    3     55    26  ...   NaN         1    NaN      4
# 40        204   153   36   2556   268  ...     7         4      5    313
# 41         28    14  NaN     72    14  ...   NaN       NaN    NaN      7
# 42        610    33  NaN    658   739  ...   302         2     13     38
# 43         76    28    2    208   123  ...     1       NaN      9     26
# 44         13     7  NaN     60    17  ...     1         2      6     14
# 45         54    12    2    155    52  ...     1         1      1     26
# 46         63    36    5    234    78  ...   NaN         1      7     78
# 47         71    45   23    191    81  ...   NaN         4      6      5
# 48         11     8  NaN     27    15  ...   NaN       NaN    NaN     16
# 49         16    11    2     38    34  ...   NaN         1      3     18
# 50         71    50   11    209    89  ...   NaN         3      4     46
# 51          9    18  NaN     24    13  ...   NaN       NaN    NaN      1
# 52         98    56    1    339   117  ...   NaN       NaN      4     26
# 53         17    25   11     91    17  ...   NaN         1      2      5
# 54       5636  3563  341  19519  6759  ...   527        79    220   2381
#
#    TESLA MOTORS TOYOTA/LEXUS VOLKSWAGEN VOLVO ALTRE  TOTALE
# 1           NaN          NaN        NaN   NaN   NaN     NaN
# 2            94          664        521    48    25    6421
# 3            20          109        132    36    10    1624
# 4            28          173        197     8    14    1748
# 5             6          117        120     7     7    2061
# 6             9           67        102     2     0     728
# 7           NaN           16         15     1     0     168
# 8             1            6         22   NaN     0     131
# 9            36          183        208    27    18    1975
# 10            2          112        145     7    10    1337
# 11            5           49         91    27     2     857
# 12           10           79         89     7     3     973
# 13            6           81        162    40     7    1386
# 14            3           40         77     5     3     752
# 15            4           34         32     7     2     490
# 16            6           38         50     4     1     511
# 17            3           51        152     6     1    1082
# 18          NaN           39         79     5     0     614
# 19            3           51         53    16     2     598
# 20            2            5         30   NaN     0     407
# 21            2           50         75    12     1     680
# 22            1           42         36     1     3     436
# 23            4           31         78    19     5     817
# 24            2           58         34     1     5     513
# 25            8           74        114    12     4    1265
# 26            1           16         13     1     0     203
# 27            5           57         43    11     2     581
# 28           66         1176        708    68    36    9483
# 29            3           32         65     6     0     409
# 30            8           46         60   NaN     5    1049
# 31          NaN           35         53     1     2     686
# 32            2           45         53    15     0     458
# 33            3           27         70   NaN     3     548
# 34            3           31         34     1     2     474
# 35            7           13         19     4     2     262
# 36            1           24         42   NaN     0     316
# 37          NaN           19         18     2     2     462
# 38            2           34         42     3     0     458
# 39            2           31         42     2     7     394
# 40           41          397        407    13    19    6898
# 41          NaN           25         46   NaN     2     349
# 42           72          253        404   184     6    7857
# 43           27          137        206    23     3    1613
# 44            1           44         32     5     3     341
# 45            4           95        118    17     2     996
# 46           20          230        179    19    14    1876
# 47           10           91        131    14     5    1286
# 48            4           14         27   NaN     1     230
# 49            9           26         27     5     2     310
# 50           31          121        237    27    10    1955
# 51            1            6          8   NaN     1     168
# 52           21          184        223    35    15    2152
# 53            1           29         35     6     0     439
# 54          923         8396      12600  1643   463  119454
#
# [54 rows x 37 columns]
#
#
# Queste sono le colonne:
#
#  Index(['PROVINCIA', 'ALFA ROMEO', 'AUDI', 'BMW', 'CHRYSLER/JEEP/DODGE',
#        'CITROEN/DS', 'DACIA', 'DR', 'FIAT', 'FORD', 'HONDA', 'HYUNDAI',
#        'JAGUAR', 'KIA', 'LANCIA', 'LAND ROVER', 'MAZDA', 'MERCEDES', 'MINI',
#        'MITSUBISHI', 'NISSAN', 'OPEL', 'PEUGEOT', 'PORSCHE', 'RENAULT', 'SEAT',
#        'SKODA', 'SMART', 'SSANGYONG', 'SUBARU', 'SUZUKI', 'TESLA MOTORS',
#        'TOYOTA/LEXUS', 'VOLKSWAGEN', 'VOLVO', 'ALTRE', 'TOTALE'],
#       dtype='object')
#
#
# Questa è la tabella con i miei brand scelti:
#
#                  DATA TOTALE
# PROVINCIA
# MESSINA     2018-1-01    876
# MESSINA     2018-2-01    755
# MESSINA     2018-3-01    946
# MESSINA     2018-4-01    765
# MESSINA     2018-5-01   1021
# MESSINA     2018-6-01    911
# MESSINA     2018-7-01    939
# MESSINA     2018-8-01    580
# MESSINA     2018-9-01    767
# MESSINA    2018-10-01    889
# MESSINA    2018-11-01    880
# MESSINA    2018-12-01    819
# MESSINA     2019-1-01    847
# MESSINA     2019-2-01    834
# MESSINA     2019-3-01    810
# MESSINA     2019-4-01    796
# MESSINA     2019-5-01    899
# MESSINA     2019-6-01    820
# MESSINA     2019-7-01    786
# MESSINA     2019-8-01    499
# MESSINA     2019-9-01    778
# MESSINA    2019-10-01    875
# MESSINA    2019-11-01    760
# MESSINA    2019-12-01    760
# MESSINA     2020-1-01    783
# MESSINA     2020-2-01    727
# MESSINA     2020-3-01    124
# MESSINA     2020-4-01     12
# MESSINA     2020-5-01    465
# MESSINA     2020-6-01    666
# MESSINA     2020-7-01    726
# MESSINA     2020-8-01    546
# MESSINA     2020-9-01    805
# MESSINA    2020-10-01    902
# MESSINA    2020-11-01    848
# MESSINA    2020-12-01    766
